# %%
from bs4 import BeautifulSoup
import pandas as pd
import csv
import os
import numpy as np
from datetime import datetime

# %% [markdown]
# # Scraping KVUE Html Files

# %%
# Web Scraped Data: 
# [KVUE Allergy Calendar](https://kvue.com/allergy)
# Scrape Monthly Allergy Calendar data as PDFs 
# save each to html
# loop through html files to make a list 

files = os.listdir('resources/html_files/cal_v2')
url = 'resources/html_files/cal_v2'

file_list = []
for f in files:
    file_list.append(url + "/" + f)  
file_list
# Out:
# ['resources/html_files/cal_v2/09_sep.html',
#  'resources/html_files/cal_v2/04_apr.html',
#  'resources/html_files/cal_v2/08_aug.html',
#  'resources/html_files/cal_v2/10_oct.html',
#  'resources/html_files/cal_v2/07_jul.html',
#  'resources/html_files/cal_v2/01_jan.html',
#  'resources/html_files/cal_v2/06_jun.html',
#  'resources/html_files/cal_v2/05_may.html',
#  'resources/html_files/cal_v2/03_mar.html',
#  'resources/html_files/cal_v2/02_feb.html']

# %%
# create list to put all the data into
raw_data = []

# %%
# loop through each html file from KVUE to scrap
for file in file_list:
    print(f'---- Processing file {file} -----')
    
    # scrape file
    soup = BeautifulSoup(open(file), "lxml")
    
    # get month & date
    month_date = soup.find('p', class_='s2').text
    month = month_date.split(' ')[0]
    year = month_date.split(' ')[1]
    
    # print(month_date)
    
    # get all the days (which are td's in the table)
    days = soup.find('table').find_all('td')
    
    #  loop through all the days and gather info for the month
    counter = 0
    calc_day = 0
    
    for day in days:
        try:
            data = day.find_all('p')

            # check to make sure we have two data elements. if two elements, we know it's actual day
            # even if the day element is empty/missing
            if len(data) > 1:
                # need a date calculator as bad html doesn't always produce a day number in the td
                calc_day +=1

                day = data[0].text
                allergens = data[1].text

                print(f'Counter {counter} Day: {day} Calc Day: {calc_day} Allergens: {allergens}')
                raw_data_dict = {}
                raw_data_dict["MonthYear"] = month_date
                raw_data_dict["Month"] = month
                raw_data_dict["Year"] = year
                raw_data_dict["Day"] = calc_day
                raw_data_dict["Allergens"] = allergens
                raw_data.append(raw_data_dict)
                
            else:
                # does not have two data elements. see if the day element has a value
                day = data[0].text
                if day != '':
                    # check to see if we already have this day in the dicitonary. 
                    # if so, skip it. just bad html formatting.
                    # if not, let's add it cuz it means no allergen data found for that day
                    if not any(data['MonthYear'] == month_date and data['Day'] == int(day) for data in raw_data):
                        print(f'Missing Allergen. Counter {counter} Day: {day}')
                        raw_data_dict = {}
                        raw_data_dict["MonthYear"] = month_date
                        raw_data_dict["Month"] = month
                        raw_data_dict["Year"] = year
                        raw_data_dict["Day"] = int(day)
                        raw_data_dict["Allergens"] = ''
                        raw_data.append(raw_data_dict)  

                        calc_day +=1
                    
        except:
            print(f'Issue for counter {counter}')
        finally:
            counter += 1
# Out:
# ---- Processing file resources/html_files/cal_v2/09_sep.html -----
# Counter 0 Day:  Calc Day: 1 Allergens: Mold Medium.
# Counter 2 Day: 2 Calc Day: 2 Allergens: Mold Medium.
# Counter 3 Day:  Calc Day: 3 Allergens: Molds High with Alternaria.
# Counter 5 Day:  Calc Day: 4 Allergens: Mold Medium
# Counter 32 Day: 28 Calc Day: 28 Allergens: Ash High 120 gr/m3, Oak Medium 53 gr/m3, Elm Medium 53 gr/m3, Mold High

# %% [markdown]
# # Transforming KVUE Data

# %%
# put the list of dictionary data into a dataframe
df = pd.DataFrame(raw_data)
df.head()
# Out:
#                                            Allergens  Day      Month  \
# 0                                       Mold Medium.    1  September
# 1                                       Mold Medium.    2  September
# 2                        Molds High with Alternaria.    3  September
# 3                                        Mold Medium    4  September
# 4  Fall Elm Low 7 gr/m3, Grass Medium 20 gr/m3, a...    5  September
#
#         MonthYear  Year
# 0  September 2019  2019
# 1  September 2019  2019
# 2  September 2019  2019
# 3  September 2019  2019
# 4  September 2019  2019

# %%
# clean up some of the data

# replace Fall Elm with just Elm
df['Allergens'].replace({'Fall Elm':'Elm'}, regex=True, inplace=True)

# # get rid of the word 'and'
df['Allergens'].replace({' and ':''}, regex=True, inplace=True)

# %%
df.head()
# Out:
#                                            Allergens  Day      Month  \
# 0                                       Mold Medium.    1  September
# 1                                       Mold Medium.    2  September
# 2                        Molds High with Alternaria.    3  September
# 3                                        Mold Medium    4  September
# 4  Elm Low 7 gr/m3, Grass Medium 20 gr/m3,Mold Me...    5  September
#
#         MonthYear  Year
# 0  September 2019  2019
# 1  September 2019  2019
# 2  September 2019  2019
# 3  September 2019  2019
# 4  September 2019  2019

# %%
# create a new formatted Date column combining Month, Day and Year fields
df['Date'] = df.apply(lambda x:datetime.strptime("{0} {1} {2}".format(x['Year'],x['Month'], x['Day']), "%Y %B %d"),axis=1)

# drop the Month, MonthYear, Year and Day columns
df.drop(['Month', 'MonthYear', 'Year', 'Day'], axis=1, inplace=True)
df.head()
# Out:
#                                            Allergens       Date
# 0                                       Mold Medium. 2019-09-01
# 1                                       Mold Medium. 2019-09-02
# 2                        Molds High with Alternaria. 2019-09-03
# 3                                        Mold Medium 2019-09-04
# 4  Elm Low 7 gr/m3, Grass Medium 20 gr/m3,Mold Me... 2019-09-05

# %%
# rearrange columns, order by date, reset index
cols = ['Date', 'Allergens']
df = df.reindex(columns=cols).sort_values('Date')
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#         Date                            Allergens
# 0 2019-01-01  Cedar Medium 346 gr/m3, Mold Medium
# 1 2019-01-02                            Mold Low.
# 2 2019-01-03                            Mold Low.
# 3 2019-01-04                            Mold Low.
# 4 2019-01-05      Cedar Low 20 gr/m3, Mold Medium

# %%
# export data to csv
df.to_csv('resources/csv_files/kvue_daily_allergens.csv', index=False)

# %% [markdown]
# ## Parse out allergens into seperate data frame with one allergen per row

# %%
# Create function that will parse out the string of allergens into a list of dictionaries
def parse_allergen(date, raw_allergen):
    '''
    Pass in index, date, and allergen, parse out what we got!
    '''
    allergens = raw_allergen.split(',')
#     allergens

    parsed_allergens = []
    for allergen in allergens:
        try:
    #         print(f'Processing allergen: {allergen}')
            # set defaults
            p_allergen = np.nan
            p_severity = np.nan
            p_measure = np.nan

            raw = allergen.strip().split(' ')
    #         print(raw)

            if len(raw) == 2:
    #             print('length of 2')
                if raw[1].find('gr/m3') == -1:
                    # not a bad parse
                    p_allergen = raw[0].replace('.', '')
                    p_severity = raw[1].replace('.', '')

            elif len(raw) == 4:
    #             print('length of 4')
                p_allergen = raw[0].replace('.', '')
                p_severity = raw[1].replace('.', '')
                if raw[3].find('gr/m3') != -1:
                    p_measure = raw[2]

            parsed = {
                'Date': date,
                'Allergen': p_allergen,
                'Severity': p_severity,
                'Measure': p_measure
            }

    #         print(f'In loop: {parsed}')

            parsed_allergens.append(parsed)
        except:
            print(f'Error parsing index {index} and allergen {allergen}')
    return parsed_allergens

# %%
# loop through daily allergen data frame, parse allergen data, add to list
daily_allergens = []
for index, row in df.iterrows():
#     print(index)
#     print(row['Allergens'])
    
    if not pd.isna(row['Allergens']):
        parsed_allergens = parse_allergen(row['Date'], row['Allergens'])

#         print(parsed_allergens)
        for p in parsed_allergens:
            daily_allergens.append(p)

#     else:
#         print('has nan')

# %%
daily_allergens
# Out:
# [{'Date': Timestamp('2019-01-01 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Medium',
#   'Measure': '346'},
#  {'Date': Timestamp('2019-01-01 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-02 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-03 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-04 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-05 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Low',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-01-05 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-06 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Low',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-01-06 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-07 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Low',
#   'Measure': '27'},
#  {'Date': Timestamp('2019-01-07 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-08 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Low',
#   'Measure': '486'},
#  {'Date': Timestamp('2019-01-08 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-09 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'High',
#   'Measure': '1232'},
#  {'Date': Timestamp('2019-01-09 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-10 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Low',
#   'Measure': '60'},
#  {'Date': Timestamp('2019-01-10 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-11 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Low',
#   'Measure': '67'},
#  {'Date': Timestamp('2019-01-11 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-12 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-13 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Medium',
#   'Measure': '326'},
#  {'Date': Timestamp('2019-01-13 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-14 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Medium',
#   'Measure': '160'},
#  {'Date': Timestamp('2019-01-14 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-15 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Medium',
#   'Measure': '100'},
#  {'Date': Timestamp('2019-01-15 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-16 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Low',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-01-16 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Moderate',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-17 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-01-17 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Moderate',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-18 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Low',
#   'Measure': '40'},
#  {'Date': Timestamp('2019-01-18 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-19 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Low',
#   'Measure': '87'},
#  {'Date': Timestamp('2019-01-19 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-20 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'High',
#   'Measure': '638'},
#  {'Date': Timestamp('2019-01-20 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-21 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Low',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-01-21 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-22 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Medium',
#   'Measure': '126'},
#  {'Date': Timestamp('2019-01-22 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-23 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Medium',
#   'Measure': '146'},
#  {'Date': Timestamp('2019-01-23 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-24 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Low',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-01-24 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-25 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Low',
#   'Measure': '220'},
#  {'Date': Timestamp('2019-01-25 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-26 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Low',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-01-26 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-27 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Low',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-01-27 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-28 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Low',
#   'Measure': '27'},
#  {'Date': Timestamp('2019-01-28 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-29 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Low',
#   'Measure': '73'},
#  {'Date': Timestamp('2019-01-29 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-30 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Medium',
#   'Measure': '86'},
#  {'Date': Timestamp('2019-01-30 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Low',
#   'Measure': '27'},
#  {'Date': Timestamp('2019-01-30 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-01-31 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Medium',
#   'Measure': '53'},
#  {'Date': Timestamp('2019-01-31 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Low',
#   'Measure': '53'},
#  {'Date': Timestamp('2019-01-31 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-02-01 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Low',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-02-01 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Low',
#   'Measure': '27'},
#  {'Date': Timestamp('2019-02-01 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-02-02 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'High',
#   'Measure': '279'},
#  {'Date': Timestamp('2019-02-02 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Medium',
#   'Measure': '147'},
#  {'Date': Timestamp('2019-02-02 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-02-03 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Low',
#   'Measure': '70'},
#  {'Date': Timestamp('2019-02-03 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-02-04 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Low',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-02-04 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-02-04 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-02-05 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'High',
#   'Measure': '93'},
#  {'Date': Timestamp('2019-02-05 00:00:00'),
#   'Allergen': 'Ash',
#   'Severity': 'Low',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-02-05 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-02-05 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-02-06 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Moderate',
#   'Measure': '66'},
#  {'Date': Timestamp('2019-02-06 00:00:00'),
#   'Allergen': 'Ash',
#   'Severity': 'Low',
#   'Measure': '47'},
#  {'Date': Timestamp('2019-02-06 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Low',
#   'Measure': '27'},
#  {'Date': Timestamp('2019-02-06 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-02-07 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'High',
#   'Measure': '506'},
#  {'Date': Timestamp('2019-02-07 00:00:00'),
#   'Allergen': 'Ash',
#   'Severity': 'High',
#   'Measure': '113'},
#  {'Date': Timestamp('2019-02-07 00:00:00'),
#   'Allergen': 'Cedar',
#   'Severity': 'Low',
#   'Measure': '40'},
#  {'Date': Timestamp('2019-02-07 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-02-08 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'High',
#   'Measure': '346'},
#  {'Date': Timestamp('2019-02-08 00:00:00'),
#   'Allergen': 'Ash',
#   'Severity': 'High',
#   'Measure': '113'},
#  {'Date': Timestamp('2019-02-08 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-02-09 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'High',
#   'Measure': '219'},
#  {'Date': Timestamp('2019-02-09 00:00:00'),
#   'Allergen': 'Ash',
#   'Severity': 'High',
#   'Measure': '93'},
#  {'Date': Timestamp('2019-02-09 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-02-10 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Low',
#   'Measure': '27'},
#  {'Date': Timestamp('2019-02-10 00:00:00'),
#   'Allergen': 'Ash',
#   'Severity': 'Low',
#   'Measure': '53'},
#  {'Date': Timestamp('2019-02-10 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-02-11 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Low',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-02-11 00:00:00'),
#   'Allergen': 'Ash',
#   'Severity': 'Low',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-02-11 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-02-12 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Medium',
#   'Measure': '33'},
#  {'Date': Timestamp('2019-02-12 00:00:00'),
#   'Allergen': 'Ash',
#   'Severity': 'Medium',
#   'Measure': '40'},
#  {'Date': Timestamp('2019-02-12 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-02-13 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Medium',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-02-13 00:00:00'),
#   'Allergen': 'Ash',
#   'Severity': 'Medium',
#   'Measure': '27'},
#  {'Date': Timestamp('2019-02-13 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-02-14 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'High',
#   'Measure': '93'},
#  {'Date': Timestamp('2019-02-14 00:00:00'),
#   'Allergen': 'Ash',
#   'Severity': 'Medium',
#   'Measure': '46'},
#  {'Date': Timestamp('2019-02-14 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-02-15 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'High',
#   'Measure': '200'},
#  {'Date': Timestamp('2019-02-15 00:00:00'),
#   'Allergen': 'Ash',
#   'Severity': 'High',
#   'Measure': '113'},
#  {'Date': Timestamp('2019-02-15 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-02-16 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'High',
#   'Measure': '3383'},
#  {'Date': Timestamp('2019-02-16 00:00:00'),
#   'Allergen': 'Ash',
#   'Severity': 'High',
#   'Measure':
00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'High',
#   'Measure': '67'},
#  {'Date': Timestamp('2019-04-05 00:00:00'),
#   'Allergen': nan,
#   'Severity': nan,
#   'Measure': nan},
#  {'Date': Timestamp('2019-04-06 00:00:00'),
#   'Allergen': 'Oak',
#   'Severity': 'High',
#   'Measure': '1519'},
#  {'Date': Timestamp('2019-04-06 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'High',
#   'Measure': '400'},
#  {'Date': Timestamp('2019-04-06 00:00:00'),
#   'Allergen': 'Ash',
#   'Severity': 'Medium',
#   'Measure': '53'},
#  {'Date': Timestamp('2019-04-06 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-04-07 00:00:00'),
#   'Allergen': 'Oak',
#   'Severity': 'Medium',
#   'Measure': '153'},
#  {'Date': Timestamp('2019-04-07 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-04-07 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-04-08 00:00:00'),
#   'Allergen': 'Oak',
#   'Severity': 'Medium',
#   'Measure': '33'},
#  {'Date': Timestamp('2019-04-08 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'High',
#   'Measure': '40'},
#  {'Date': Timestamp('2019-04-08 00:00:00'),
#   'Allergen': 'Ash',
#   'Severity': 'Low',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-04-08 00:00:00'),
#   'Allergen': nan,
#   'Severity': nan,
#   'Measure': nan},
#  {'Date': Timestamp('2019-04-09 00:00:00'),
#   'Allergen': 'Oak',
#   'Severity': 'High',
#   'Measure': '892'},
#  {'Date': Timestamp('2019-04-09 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'High',
#   'Measure': '46'},
#  {'Date': Timestamp('2019-04-09 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-04-10 00:00:00'),
#   'Allergen': 'Oak',
#   'Severity': 'High',
#   'Measure': '140'},
#  {'Date': Timestamp('2019-04-10 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'High',
#   'Measure': '46'},
#  {'Date': Timestamp('2019-04-10 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-04-11 00:00:00'),
#   'Allergen': 'Oak',
#   'Severity': 'Medium',
#   'Measure': '67'},
#  {'Date': Timestamp('2019-04-11 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-04-11 00:00:00'),
#   'Allergen': 'Ash',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-04-11 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-04-12 00:00:00'),
#   'Allergen': 'Oak',
#   'Severity': 'High',
#   'Measure': '912'},
#  {'Date': Timestamp('2019-04-12 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-04-12 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-04-13 00:00:00'),
#   'Allergen': 'Oak',
#   'Severity': 'High',
#   'Measure': '306'},
#  {'Date': Timestamp('2019-04-13 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'High',
#   'Measure': '153'},
#  {'Date': Timestamp('2019-04-13 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-04-14 00:00:00'),
#   'Allergen': 'Oak',
#   'Severity': 'High',
#   'Measure': '233'},
#  {'Date': Timestamp('2019-04-14 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'High',
#   'Measure': '53'},
#  {'Date': Timestamp('2019-04-14 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-04-15 00:00:00'),
#   'Allergen': 'Oak',
#   'Severity': 'Medium',
#   'Measure': '27'},
#  {'Date': Timestamp('2019-04-15 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-04-15 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-04-16 00:00:00'),
#   'Allergen': 'Oak',
#   'Severity': 'Low',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-04-16 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-04-16 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-04-17 00:00:00'),
#   'Allergen': 'Oak',
#   'Severity': 'High',
#   'Measure': '100'},
#  {'Date': Timestamp('2019-04-17 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-04-17 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-04-18 00:00:00'),
#   'Allergen': 'Oak',
#   'Severity': 'Medium',
#   'Measure': '60'},
#  {'Date': Timestamp('2019-04-18 00:00:00'),
#   'Allergen': nan,
#   'Severity': nan,
#   'Measure': nan},
#  {'Date': Timestamp('2019-04-19 00:00:00'),
#   'Allergen': 'Oak',
#   'Severity': 'High',
#   'Measure': '93'},
#  {'Date': Timestamp('2019-04-19 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'High',
#   'Measure': '47'},
#  {'Date': Timestamp('2019-04-19 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-04-20 00:00:00'),
#   'Allergen': 'Oak',
#   'Severity': 'Medium',
#   'Measure': '67'},
#  {'Date': Timestamp('2019-04-20 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-04-20 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-04-21 00:00:00'),
#   'Allergen': 'Oak',
#   'Severity': 'Medium',
#   'Measure': '80'},
#  {'Date': Timestamp('2019-04-21 00:00:00'),
#   'Allergen': 'Pecan',
#   'Severity': 'Medium',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-04-21 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-04-21 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-04-22 00:00:00'),
#   'Allergen': 'Oak',
#   'Severity': 'Medium',
#   'Measure': '53'},
#  {'Date': Timestamp('2019-04-22 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-04-22 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-04-23 00:00:00'),
#   'Allergen': 'Oak',
#   'Severity': 'Medium',
#   'Measure': '33'},
#  {'Date': Timestamp('2019-04-23 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'High',
#   'Measure': '27'},
#  {'Date': Timestamp('2019-04-23 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-04-24 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-04-25 00:00:00'),
#   'Allergen': 'Oak',
#   'Severity': 'Medium',
#   'Measure': '47'},
#  {'Date': Timestamp('2019-04-25 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-04-25 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-04-26 00:00:00'),
#   'Allergen': 'Oak',
#   'Severity': 'Medium',
#   'Measure': '53'},
#  {'Date': Timestamp('2019-04-26 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-04-26 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-04-27 00:00:00'),
#   'Allergen': 'Oak',
#   'Severity': 'Medium',
#   'Measure': '40'},
#  {'Date': Timestamp('2019-04-27 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'High',
#   'Measure': '80'},
#  {'Date': Timestamp('2019-04-27 00:00:00'),
#   'Allergen': 'Pecan',
#   'Severity': 'Medium',
#   'Measure': '87'},
#  {'Date': Timestamp('2019-04-27 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-04-28 00:00:00'),
#   'Allergen': 'Pecan',
#   'Severity': 'Medium',
#   'Measure': '27'},
#  {'Date': Timestamp('2019-04-28 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-04-29 00:00:00'),
#   'Allergen': 'Oak',
#   'Severity': 'Low',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-04-29 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'High',
#   'Measure': '67'},
#  {'Date': Timestamp('2019-04-29 00:00:00'),
#   'Allergen': 'Pecan',
#   'Severity': 'Medium',
#   'Measure': '53'},
#  {'Date': Timestamp('2019-04-29 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-04-30 00:00:00'),
#   'Allergen': 'Pecan',
#   'Severity': 'Low',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-04-30 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'High',
#   'Measure': '33'},
#  {'Date': Timestamp('2019-04-30 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-01 00:00:00'),
#   'Allergen': 'Pecan',
#   'Severity': 'Low',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-05-01 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-05-01 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-02 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-03 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-04 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-05 00:00:00'),
#   'Allergen': 'Oak',
#   'Severity': 'Low',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-05-05 00:00:00'),
#   'Allergen': 'Pecan',
#   'Severity': 'Medium',
#   'Measure': '27'},
#  {'Date': Timestamp('2019-05-05 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-05-05 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-06 00:00:00'),
#   'Allergen': nan,
#   'Severity': nan,
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-07 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-05-07 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-08 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-09 00:00:00'),
#   'Allergen': 'Pecan',
#   'Severity': 'Low',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-05-09 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-10 00:00:00'),
#   'Allergen': 'Pecan',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-05-10 00:00:00'),
#   'Allergen': nan,
#   'Severity': nan,
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-10 00:00:00'),
#   'Allergen': nan,
#   'Severity': nan,
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-11 00:00:00'),
#   'Allergen': 'Pecan',
#   'Severity': 'Medium',
#   'Measure': '73'},
#  {'Date': Timestamp('2019-05-11 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-05-11 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-12 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-13 00:00:00'),
#   'Allergen': 'Pecan',
#   'Severity': 'Low',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-05-13 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-05-13 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-14 00:00:00'),
#   'Allergen': 'Pecan',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-05-14 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'High',
#   'Measure': '33'},
#  {'Date': Timestamp('2019-05-14 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-15 00:00:00'),
#   'Allergen': 'Pecan',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-05-15 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'High',
#   'Measure': '33'},
#  {'Date': Timestamp('2019-05-15 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-16 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'High',
#   'Measure': '27'},
#  {'Date': Timestamp('2019-05-16 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-17 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'High',
#   'Measure': '33'},
#  {'Date': Timestamp('2019-05-17 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-18 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-19 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-20 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-05-20 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-21 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'High',
#   'Measure': '27'},
#  {'Date': Timestamp('2019-05-21 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-22 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'High',
#   'Measure': '40'},
#  {'Date': Timestamp('2019-05-22 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-23 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-05-23 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-24 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-05-24 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-25 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-26 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-27 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-28 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-05-28 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-29 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-05-29 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-30 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-05-30 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-05-31 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-06-01 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-06-01 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-06-02 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-06-03 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-06-03 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-06-04 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'High',
#   'Measure': '27'},
#  {'Date': Timestamp('2019-06-04 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-06-05 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-06-05 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-06-06 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-06-06 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-06-07 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-06-08 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-06-09 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-06-09 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-06-11 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-06-11 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-06-12 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-06-12 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-06-13 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'High',
#   'Measure': '27'},
#  {'Date': Timestamp('2019-06-13 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-06-14 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'High',
#   'Measure': '33'},
#  {'Date': Timestamp('2019-06-14 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-06-15 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'High',
#   'Measure': '27'},
#  {'Date': Timestamp('2019-06-15 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-06-16 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-06-16 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-06-17 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-06-18 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-06-18 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-06-19 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-06-19 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-06-20 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-06-21 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-06-21 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-06-22 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': '7',
#   'Measure': 'Low'},
#  {'Date': Timestamp('2019-06-22 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-06-23 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-06-24 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-06-27 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
# ...
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-07-26 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-07-27 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-07-28 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-07-28 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-07-29 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-07-29 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-07-30 00:00:00'),
#   'Allergen': 'No',
#   'Severity': 'data',
#   'Measure': nan},
#  {'Date': Timestamp('2019-07-31 00:00:00'),
#   'Allergen': 'No',
#   'Severity': 'data',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-01 00:00:00'),
#   'Allergen': 'Molds',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-02 00:00:00'),
#   'Allergen': 'Molds',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-03 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-08-03 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-04 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-05 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-06 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-07 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-08 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-09 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-08-09 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-10 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-08-10 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-11 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-12 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-08-12 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-13 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-08-13 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-14 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-08-14 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-15 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-16 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-08-16 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-17 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-08-17 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-18 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-19 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-20 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-21 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-22 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-08-22 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-23 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-24 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-25 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-26 00:00:00'),
#   'Allergen': 'Molds',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-27 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-28 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-29 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-08-29 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-30 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-08-30 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-08-31 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-01 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-02 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-03 00:00:00'),
#   'Allergen': 'Molds',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-04 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-05 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-09-05 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-09-05 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-06 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-07 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-08 00:00:00'),
#   'Allergen': 'Grass',
#   'Severity': 'Medium',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-09-08 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-09 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'medium',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-09-09 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-10 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-09-10 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-11 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-09-11 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-12 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'Medium',
#   'Measure': '27'},
#  {'Date': Timestamp('2019-09-12 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-13 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'Medium',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-09-13 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Medium',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-14 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'Medium',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-09-14 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'Low',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-15 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'Medium',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-09-15 00:00:00'),
#   'Allergen': 'Molds',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-16 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'High',
#   'Measure': '53'},
#  {'Date': Timestamp('2019-09-16 00:00:00'),
#   'Allergen': 'Molds',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-17 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'Low',
#   'Measure': '7'},
#  {'Date': Timestamp('2019-09-17 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-18 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'High',
#   'Measure': '127'},
#  {'Date': Timestamp('2019-09-18 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-19 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'High',
#   'Measure': '106'},
#  {'Date': Timestamp('2019-09-19 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-20 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'High',
#   'Measure': '133'},
#  {'Date': Timestamp('2019-09-20 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-21 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'High',
#   'Measure': '60'},
#  {'Date': Timestamp('2019-09-21 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-23 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'Medium',
#   'Measure': '47'},
#  {'Date': Timestamp('2019-09-23 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-23 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Low',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-09-24 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'High',
#   'Measure': '133'},
#  {'Date': Timestamp('2019-09-24 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-24 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Med',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-09-25 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'High',
#   'Measure': '80'},
#  {'Date': Timestamp('2019-09-25 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-25 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Med',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-09-26 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'High',
#   'Measure': '107'},
#  {'Date': Timestamp('2019-09-26 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-26 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Med',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-09-27 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'High',
#   'Measure': '117'},
#  {'Date': Timestamp('2019-09-27 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-27 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Med',
#   'Measure': '27'},
#  {'Date': Timestamp('2019-09-28 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'High',
#   'Measure': '66'},
#  {'Date': Timestamp('2019-09-28 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Medium',
#   'Measure': '20'},
#  {'Date': Timestamp('2019-09-28 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-29 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'High',
#   'Measure': '60'},
#  {'Date': Timestamp('2019-09-29 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Low',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-09-29 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-09-30 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'High',
#   'Measure': '67'},
#  {'Date': Timestamp('2019-09-30 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Low',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-09-30 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-10-01 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'High',
#   'Measure': '54'},
#  {'Date': Timestamp('2019-10-01 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Low',
#   'Measure': '13'},
#  {'Date': Timestamp('2019-10-01 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-10-02 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'High',
#   'Measure': '153'},
#  {'Date': Timestamp('2019-10-02 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Med',
#   'Measure': '54'},
#  {'Date': Timestamp('2019-10-02 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-10-03 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'High',
#   'Measure': '200'},
#  {'Date': Timestamp('2019-10-03 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Med',
#   'Measure': '27'},
#  {'Date': Timestamp('2019-10-03 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-10-04 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'High',
#   'Measure': '153'},
#  {'Date': Timestamp('2019-10-04 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Med',
#   'Measure': '33'},
#  {'Date': Timestamp('2019-10-04 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-10-05 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'High',
#   'Measure': '127'},
#  {'Date': Timestamp('2019-10-05 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Med',
#   'Measure': '40'},
#  {'Date': Timestamp('2019-10-05 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-10-06 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'High',
#   'Measure': '133'},
#  {'Date': Timestamp('2019-10-06 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Med',
#   'Measure': '27'},
#  {'Date': Timestamp('2019-10-06 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-10-07 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'High',
#   'Measure': '147'},
#  {'Date': Timestamp('2019-10-07 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Med',
#   'Measure': '40'},
#  {'Date': Timestamp('2019-10-07 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-10-08 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'High',
#   'Measure': '186'},
#  {'Date': Timestamp('2019-10-08 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Med',
#   'Measure': '27'},
#  {'Date': Timestamp('2019-10-08 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-10-09 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'High',
#   'Measure': '206'},
#  {'Date': Timestamp('2019-10-09 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Med',
#   'Measure': '33'},
#  {'Date': Timestamp('2019-10-09 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-10-10 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'High',
#   'Measure': '147'},
#  {'Date': Timestamp('2019-10-10 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Med',
#   'Measure': '47'},
#  {'Date': Timestamp('2019-10-10 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-10-11 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'High',
#   'Measure': '100'},
#  {'Date': Timestamp('2019-10-11 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Med',
#   'Measure': '33'},
#  {'Date': Timestamp('2019-10-11 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan},
#  {'Date': Timestamp('2019-10-12 00:00:00'),
#   'Allergen': 'Ragweed',
#   'Severity': 'Medium',
#   'Measure': '80'},
#  {'Date': Timestamp('2019-10-12 00:00:00'),
#   'Allergen': 'Elm',
#   'Severity': 'Med',
#   'Measure': '27'},
#  {'Date': Timestamp('2019-10-12 00:00:00'),
#   'Allergen': 'Mold',
#   'Severity': 'High',
#   'Measure': nan}]

# %%
# put daily allergens into dataframe
df_allergens_speciated = pd.DataFrame(daily_allergens)
df_allergens_speciated.head()
# Out:
#   Allergen       Date Measure Severity
# 0    Cedar 2019-01-01     346   Medium
# 1     Mold 2019-01-01     NaN   Medium
# 2     Mold 2019-01-02     NaN      Low
# 3     Mold 2019-01-03     NaN      Low
# 4     Mold 2019-01-04     NaN      Low

# %%
# rearrange columns, order by date, reset index
cols = ['Date', 'Allergen', 'Severity', 'Measure']
df_allergens_speciated = df_allergens_speciated.reindex(columns=cols).sort_values('Date')
df_allergens_speciated.reset_index(drop=True, inplace=True)
df_allergens_speciated.head()
# Out:
#         Date Allergen Severity Measure
# 0 2019-01-01    Cedar   Medium     346
# 1 2019-01-01     Mold   Medium     NaN
# 2 2019-01-02     Mold      Low     NaN
# 3 2019-01-03     Mold      Low     NaN
# 4 2019-01-04     Mold      Low     NaN

# %%
# export data to csv
df_allergens_speciated.to_csv('resources/csv_files/kvue_daily_allergens_speciated.csv', index=False)

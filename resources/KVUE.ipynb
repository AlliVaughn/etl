# %%
from splinter import Browser
from bs4 import BeautifulSoup
import re
from selenium import webdriver
import json

# %%
# !which chromedriver

# %%
executable_path = {'executable_path': './chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = 'https://www.kvue.com/allergy'
browser.visit(url)

# %%
html = browser.html
soup = BeautifulSoup(html, "lxml")

# %%
# selector >> calcontent_0_0 > div > div > div > span
# <span class="calEventDisplay_text "

allergens = soup.select('div')
allergens
# Out:
# [<div class="fb_reset" id="fb-root"><div style="position: absolute; top: -10000px; width: 0px; height: 0px;"><div></div></div></div>,
#  <div style="position: absolute; top: -10000px; width: 0px; height: 0px;"><div></div></div>,
#  <div></div>,
#  <div class="page__notifications">
#  <div class="notifications" style="">
#  <div class="notifications__logo-container">
#  <img class="notifications__logo" src="/Content/logos/dark/kvue.png"/>
#  </div>
#  <h2 class="notifications__heading">KVUE.com would like to send you push notifications about the latest news and weather.</h2>
#  <p class="notifications__description">Notifications can be turned off anytime in the browser settings.</p>
#  <div class="notifications__buttons">
#  <button class="notifications__button notifications__button_option_no notifications__button_default_false">No Thanks</button>
#  <button class="notifications__button notifications__button_option_yes notifications__button_default_true">Allow</button>
#  </div>
#  </div>
#  </div>,
#  <div class="notifications" style="">
#  <div class="notifications__logo-container">
#  <img class="notifications__logo" src="/Content/logos/dark/kvue.png"/>
#  </div>
#  <h2 class="notifications__heading">KVUE.com would like to send you push notifications about the latest news and weather.</h2>
#  <p class="notifications__description">Notifications can be turned off anytime in the browser settings.</p>
#  <div class="notifications__buttons">
#  <button class="notifications__button notifications__button_option_no notifications__button_default_false">No Thanks</button>
#  <button class="notifications__button notifications__button_option_yes notifications__button_default_true">Allow</button>
#  </div>
#  </div>,
#  <div class="notifications__logo-container">
#  <img class="notifications__logo" src="/Content/logos/dark/kvue.png"/>
#  </div>,
#  <div class="notifications__buttons">
#  <button class="notifications__button notifications__button_option_no notifications__button_default_false">No Thanks</button>
#  <button class="notifications__button notifications__button_option_yes notifications__button_default_true">Allow</button>
#  </div>,
#  <div class="page__container page__container_universal-ad-enabled_false page__container_show-universal-ad_false">
#  <div class="page__desktop-header page__desktop-header_universal-ad-mode_closed">
#  <div class="desktop-header">
#  <div class="desktop-header__wrap">
#  <div class="desktop-header__inner">
#  <div class="desktop-header__main">
#  <div class="desktop-header__toolbar">
#  <div class="toolbar">
#  <div class="toolbar__live-indicator">
#  <div class="live-indicator live-indicator_collapsed_false">
#  <div class="live-indicator__info live-indicator__info_visible_true">
#  <div class="live-indicator__cta">
#  <div class="live-indicator__watch-live">WATCH LIVE</div>
#  <div class="live-indicator__watch-time">On Air 9:55PM</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="toolbar__weather-summary">
#  <div class="weather-summary">
#  <a class="weather-summary__link" data-tracking="weather-summary/weatherClicked" href="/weather">
#  <div class="weather-summary__icon weather-icons weather-icons_icon_67"></div>
#  <span class="weather-summary__current-temperature">57</span>
#  <div class="weather-summary__location">Austin, TX</div>
#  <div class="weather-summary__weather-conditions-container">
#  <p class="weather-summary__weather-conditions">Austin Weather Summary: 57 degrees</p>
#  </div>
#  </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="desktop-header__nav-button"><div class="desktop-header__nav-label">Menu</div></div>
#  <div class="desktop-header__badges">
#  <a class="desktop-header__badge desktop-header__badge_type_live desktop-header__badge_visible_false" data-tracking="desktop-header/blipClicked" data-type="live" href="/live-video"></a>
#  <a class="desktop-header__badge desktop-header__badge_type_breaking desktop-header__badge_visible_false" data-tracking="desktop-header/blipClicked" data-type="breaking" href="/breaking-news"></a>
#  <a class="desktop-header__badge desktop-header__badge_type_weather desktop-header__badge_visible_false" data-tracking="desktop-header/blipClicked" data-type="weather" href="/severe-weather"></a>
#  <a class="desktop-header__badge desktop-header__badge_type_closing desktop-header__badge_visible_false" data-tracking="desktop-header/blipClicked" data-type="closing" href="/closings"></a>
#  </div>
#  <a class="desktop-header__home-link desktop-header__home-link_visible_true" data-tracking="desktop-header/homeLinkClicked" href="/">
#  <img class="desktop-header__logo" src="/content/logos/mobile/kvue.png"/>
#  </a>
#  <div class="desktop-header__article-title"></div>
#  </div>
#  </div>
#  <div class="desktop-header__progress desktop-header__progress_visible_false">
#  <progress class="progress" value="0"></progress>
#  </div>
#  </div>
#  <div class="desktop-header__nav-wrapper">
#  <div class="desktop-header__navigation desktop-header__navigation_visible_false">
#  <div class="navigation navigation_visible_false">
#  <div class="navigation__main">
#  <div class="navigation__main-inner">
#  <div class="navigation__searchbox">
#  <div class="searchbox">
#  <form action="/search" class="searchbox__form">
#  <div class="searchbox__main">
#  <input class="searchbox__textbox searchbox__textbox_name_q" name="q" placeholder="Search"/>
#  <button class="searchbox__submit" type="submit"></button>
#  </div>
#  <label class="searchbox__labeled-field">
#  <input checked="" class="searchbox__checkbox searchbox__checkbox_name_phrase" name="phrase" type="checkbox"/>
#  <span class="searchbox__label">Exact phrase</span>
#  </label>
#  </form>
#  </div>
#  </div>
#  <div class="navigation__notification-container">
#  <div class="navigation__notification">
#  <div class="navigation__notification-title">KVUE Alert Center</div>
#  <div class="navigation__notification-list">
#  <a class="navigation__notification-label navigation__notification-label_name_live-videos navigation__notification-label_active_false" data-tracking="navigation/alertCenterClicked" href="/live-video">Live Video</a>
#  <a class="navigation__notification-label navigation__notification-label_name_breaking-news navigation__notification-label_active_false" data-tracking="navigation/alertCenterClicked" href="/breaking-news">Breaking<br/>News</a>
#  <a class="navigation__notification-label navigation__notification-label_name_weather navigation__notification-label_active_false" data-tracking="navigation/alertCenterClicked" href="/severe-weather">Weather</a>
#  <a class="navigation__notification-label navigation__notification-label_name_closings navigation__notification-label_active_false" data-tracking="navigation/alertCenterClicked" href="/closings">Delays/<br/>Closings</a>
#  </div>
#  </div>
#  </div>
#  <ul class="navigation__sponsored-list">
#  <li class="navigation__sponsored-by">Sponsored by</li>
#  <li class="navigation__sponsored-item">
#  <a class="navigation__sponsored-link" data-tracking="navigation/sponsoredLinkClicked" href="/homeless">
#  <img alt="Homeless" class="navigation__sponsored-image" src="https://cdn.tegna-media.com/wbir/assets/kvue-homeless-352x52.jpg"/>
#  <div class="navigation__sponsored-go-indicator"></div>
#  </a>
#  </li>
#  <li class="navigation__sponsored-item">
#  <a class="navigation__sponsored-link" data-tracking="navigation/sponsoredLinkClicked" href="/section/entertainment/events/austin-city-limits">
#  <img alt="Austin City Limits" class="navigation__sponsored-image" src="https://cdn.tegna-media.com/kvue/assets/austin-city-music-festival.png"/>
#  <div class="navigation__sponsored-go-indicator"></div>
#  </a>
#  </li>
#  <li class="navigation__sponsored-item">
#  <a class="navigation__sponsored-link" data-tracking="navigation/sponsoredLinkClicked" href="/boomtown2040">
#  <img alt="Boomtown 2040" class="navigation__sponsored-image" src="https://cdn.tegna-media.com/wbir/assets/boomtown2040-352x52.jpg"/>
#  <div class="navigation__sponsored-go-indicator"></div>
#  </a>
#  </li>
#  </ul>
#  <noscript>
#              &lt;div class="navigation__item navigation__item_children_false" style="border-top:1px solid #e6e6e6"&gt;
#                  &lt;a class="navigation__sublist-activator" href="/"&gt;
#                      &lt;span class="navigation__label"&gt;Home&lt;/span&gt;
#                  &lt;/a&gt;
#              &lt;/div&gt;
#          </noscript>
#  <ul class="navigation__list">
#  <li class="navigation__item navigation__item_children_true">
#  <div class="navigation__sublist-activator">
#  <span class="navigation__label navigation__label_section_news" href="/news">News</span>
#  <span class="navigation__expansion-indicator navigation__expansion-indicator_expanded_true"></span>
#  </div>
#  <ul class="navigation__sublist navigation__sublist_special_true navigation__sublist_visible_true">
#  <li class="navigation__subitem navigation__subitem_special_true"><a class="navigation__sublink navigation__sublink_section_local navigation__sublink_special_true" data-tracking="navigation/linkClicked" href="/local">Local</a></li>
#  <li class="navigation__subitem navigation__subitem_special_true"><a class="navigation__sublink navigation__sublink_section_money navigation__sublink_special_true" data-tracking="navigation/linkClicked" href="/money">Money</a></li>
#  <li class="navigation__subitem navigation__subitem_special_true"><a class="navigation__sublink navigation__sublink_section_entertainment-news navigation__sublink_special_true" data-tracking="navigation/linkClicked" href="/entertainment">Entertainment</a></li>
#  <li class="navigation__subitem navigation__subitem_special_true"><a class="navigation__sublink navigation__sublink_section_news-nationnow navigation__sublink_special_true" data-tracking="navigation/linkClicked" href="/nation-now">Nation World</a></li>
#  <li class="navigation__subitem navigation__subitem_special_true"><a class="navigation__sublink navigation__sublink_section_news-health navigation__sublink_special_true" data-tracking="navigation/linkClicked" href="/health">Health</a></li>
#  <li class="navigation__subitem navigation__subitem_special_true"><a class="navigation__sublink navigation__sublink_section_news-politics navigation__sublink_special_true" data-tracking="navigation/linkClicked" href="/politics">Politics</a></li>
#  <li class="navigation__subitem navigation__subitem_special_true"><a class="navigation__sublink navigation__sublink_section_life navigation__sublink_special_true" data-tracking="navigation/linkClicked" href="/life">Life</a></li>
#  <li class="navigation__subitem navigation__subitem_special_true"><a class="navigation__sublink navigation__sublink_section_news-investigations navigation__sublink_special_true" data-tracking="navigation/linkClicked" href="/defenders">Defenders</a></li>
#  <li class="navigation__subitem navigation__subitem_special_true"><a class="navigation__sublink navigation__sublink_section_community navigation__sublink_special_true" data-tracking="navigation/linkClicked" href="/community">Community</a></li>
#  </ul>
#  </li>
#  <li class="navigation__item navigation__item_children_true">
#  <div class="navigation__sublist-activator">
#  <span class="navigation__label navigation__label_section_weathertraffic" href="/weather/">Weather &amp; Traffic</span>
#  <span class="navigation__expansion-indicator"></span>
#  </div>
#  <ul class="navigation__sublist navigation__sublist_visible_false">
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_weather" data-tracking="navigation/linkClicked" href="/weather">Current Weather</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_weather~radar" data-tracking="navigation/linkClicked" href="/radar">Radar</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_weather~maps" data-tracking="navigation/linkClicked" href="/weather-maps">Maps</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_weather~7-day" data-tracking="navigation/linkClicked" href="/10-day">Hourly &amp; 10-Day</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_weather~closings" data-tracking="navigation/linkClicked" href="/closings">Closings &amp; Delays</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_weather" data-tracking="navigation/linkClicked" href="/weathercams">Weather Cams</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_weather~extra" data-tracking="navigation/linkClicked" href="/weatherblogs">Weather Blogs</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_traffic" data-tracking="navigation/linkClicked" href="/traffic">Traffic</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_traffic~gas-prices" data-tracking="navigation/linkClicked" href="/gas-prices">Gas Prices</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_traffic~driving-smart" data-tracking="navigation/linkClicked" href="/driving-smart">Driving Smart</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_traffic" data-tracking="navigation/linkClicked" href="https://www.cars.com" target='"_blank"'>Cars.com</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_weather~allergy-forecast" data-tracking="navigation/linkClicked" href="/allergy">Allergy</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_weather~weather-snapshot" data-tracking="navigation/linkClicked" href="/weather-snapshot">Weather Snapshot</a><div class="navigation__go-indicator"></div></li>
#  </ul>
#  </li>
#  <li class="navigation__item navigation__item_children_true">
#  <div class="navigation__sublist-activator">
#  <span class="navigation__label navigation__label_section_sports" href="/sports">Sports</span>
#  <span class="navigation__expansion-indicator"></span>
#  </div>
#  <ul class="navigation__sublist navigation__sublist_visible_false">
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_sports" data-tracking="navigation/linkClicked" href="/sports">Latest Sports</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_sports~high-school" data-tracking="navigation/linkClicked" href="/hss">High School Sports</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_sports~ncaa~longhorns" data-tracking="navigation/linkClicked" href="/longhorns">Longhorns</a><div class="navigation__go-indicator"></div></li>
#  </ul>
#  </li>
#  <li class="navigation__item navigation__item_children_true">
#  <div class="navigation__sublist-activator">
#  <span class="navigation__label navigation__label_section_features" href="/features">Features</span>
#  <span class="navigation__expansion-indicator"></span>
#  </div>
#  <ul class="navigation__sublist navigation__sublist_visible_false">
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_news~special-reports~at-the-border" data-tracking="navigation/linkClicked" href="/attheborder">At the Border</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_news~local~austin-explosions" data-tracking="navigation/linkClicked" href="/austinexplosions">Austin Explosions</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_news~local-news~austin-pride" data-tracking="navigation/linkClicked" href="/pride">Austin PRIDE</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_money~economy~boomtown" data-tracking="navigation/linkClicked" href="/boomtown2040">Boomtown2040</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_money~consumer" data-tracking="navigation/linkClicked" href="/consumer">Consumer</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_features-contests" data-tracking="navigation/linkClicked" href="/contests">Contests</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_news~health~cosmetic-minute" data-tracking="navigation/linkClicked" href="/cosmeticminute">Cosmetic Minute</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_travel~destinations~daybreak-adventures" data-tracking="navigation/linkClicked" href="/daybreakadventures">Daybreak Adventures</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_money~consumer~does-it-work" data-tracking="navigation/linkClicked" href="/doesitwork">Does It Work?</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_news~local~outreach~five-who-care" data-tracking="navigation/linkClicked" href="/fivewhocare">Five Who Care</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_life~food" data-tracking="navigation/linkClicked" href="/food">Food</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_life~food~foodie-friday" data-tracking="navigation/linkClicked" href="/foodiefriday">Foodie Friday</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_features~fyi-austin" data-tracking="navigation/linkClicked" href="/fyi">FYI Austin</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_news~local~homeless" data-tracking="navigation/linkClicked" href="/homeless">Homeless</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_life~house-scout" data-tracking="navigation/linkClicked" href="/house-scout">House Scout</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_features~lifestyles" data-tracking="navigation/linkClicked" href="/lifestyles">Lifestyles</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_news~investigations~medical-device-dangers" data-tracking="navigation/linkClicked" href="/medical-device-dangers">Medical Device Dangers</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_news~local~contests" data-tracking="navigation/linkClicked" href="/payitforward">Pay It Forward</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_life~pets" data-tracking="navigation/linkClicked" href="/pets">Pets</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_news~local~project-green" data-tracking="navigation/linkClicked" href="/project-green">Project Green</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_life~family~sandwich-generation" data-tracking="navigation/linkClicked" href="/sandwichgeneration">Sandwich Generation</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_news~education~schools" data-tracking="navigation/linkClicked" href="/schools">Schools</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_sports~high-school~scholar-athlete" data-tracking="navigation/linkClicked" href="/scholarathleteofthemonth">Scholar Athlete of the Month</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_news~local~outreach~spirit-of-caring" data-tracking="navigation/linkClicked" href="/spiritofcaring">Spirit of Caring</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_money~economy~take-this-job" data-tracking="navigation/linkClicked" href="/takethisjob">Take This Job</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_tech" data-tracking="navigation/linkClicked" href="/tech">Technology</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_tech~tech-tuesday" data-tracking="navigation/linkClicked" href="/techtuesday">Tech Tuesday</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_news~local~texas-news" data-tracking="navigation/linkClicked" href="/texas">Texas</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_news~politics~texas-legislature" data-tracking="navigation/linkClicked" href="/texas-legislature">Texas Legislature</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_news~politics~texas-this-week" data-tracking="navigation/linkClicked" href="/section/news/politics/texas-this-week">Texas This Week</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_news~education~university-of-texas" data-tracking="navigation/linkClicked" href="/universityoftexas">University of Texas</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_news~local~verify" data-tracking="navigation/linkClicked" href="/verify">Verify</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_news~politics~vote-texas" data-tracking="navigation/linkClicked" href="/votetexas">Vote Texas</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_entertainment" data-tracking="navigation/linkClicked" href="https://abc.go.com/?aff=kvue" target='"_blank"'>Watch ABC Shows</a><div class="navigation__go-indicator"></div></li>
#  </ul>
#  </li>
#  <li class="navigation__item navigation__item_children_true">
#  <div class="navigation__sublist-activator">
#  <span class="navigation__label navigation__label_section_media" href="/video">Media</span>
#  <span class="navigation__expansion-indicator"></span>
#  </div>
#  <ul class="navigation__sublist navigation__sublist_visible_false">
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_news" data-tracking="navigation/linkClicked" href="/video">Video</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_news" data-tracking="navigation/linkClicked" href="/gallery" target='"_blank"'>Photos</a><div class="navigation__go-indicator"></div></li>
#  </ul>
#  </li>
#  <li class="navigation__item navigation__item_children_true">
#  <div class="navigation__sublist-activator">
#  <span class="navigation__label navigation__label_section_connect" href="/connect">Connect</span>
#  <span class="navigation__expansion-indicator"></span>
#  </div>
#  <ul class="navigation__sublist navigation__sublist_visible_false">
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_about-us" data-tracking="navigation/linkClicked" href="/about-us">About Us</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_about-us~contact-us" data-tracking="navigation/linkClicked" href="/contact-us">Contact Us</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_about-us" data-tracking="navigation/linkClicked" href="/advertise">Advertise With Us</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_about-us" data-tracking="navigation/linkClicked" href="https://www.jobs.net/jobs/tegna/en-us/all-jobs/?companyf=KVUE" target='"_blank"'>Jobs</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_about-us" data-tracking="navigation/linkClicked" href="/meet-the-team">Meet the Team</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_about-us" data-tracking="navigation/linkClicked" href="/email">Newsletter</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink navigation__sublink_section_about-us" data-tracking="navigation/linkClicked" href="/tv-listings">TV Listings</a><div class="navigation__go-indicator"></div></li>
#  <li class="navigation__subitem"><a class="navigation__sublink" data-tracking="navigation/linkClicked" href="http://yourphotos.kvue.com">Your Photos</a><div class="navigation__go-indicator"></div></li>
#  </ul>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <div class="navigation__footer">
#  <div class="navigation__live-indicator">
#  </div>
#  <div class="navigation__social">
#  <a href="https://www.facebook.com/KVUEinsider" target="_blank"><div class="navigation__icon navigation__icon_facebook"></div></a>
#  <a href="https://twitter.com/intent/user?screen_name=KVUE" target="_blank"><div class="navigation__icon navigation__icon_twitter"></div></a>
#  </div>
#  <ul class="navigation__extra-links">
#  </ul>
#  <div class="navigation__copyright">© 2019 KVUE-TV. All Rights Reserved.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="page__main page__main_stand-alone_false page__main_show-universal-ad_false">
#  <div class="page__modal-overlay"></div>
#  <div class="page__toasts">
#  <div class="toasts">
#  <script class="toasts__toast-template" type="text/template">
#          &lt;div class="toasts__toast toasts__toast_new_true"&gt;
#              &lt;div class="toasts__logo-container"&gt;
#                  &lt;img class="toasts__logo" src="/Content/logos/dark/kvue.png" /&gt;
#              &lt;/div&gt;
#              &lt;div class="toasts__close"&gt;×&lt;/div&gt;
#              &lt;div class="toasts__content"&gt;
#                  &lt;div class="toasts__title"&gt;&lt;/div&gt;
#                  &lt;div class="toasts__body"&gt;&lt;/div&gt;
#                  &lt;p class="toasts__link"&gt;Read More&lt;/p&gt;
#              &lt;/div&gt;
#          &lt;/div&gt;
#      </script>
#  </div>
#  </div>
#  <div class="page__grid">
#  <div class="grid">
#  <div class="grid__section-group grid__section-group_theme_default">
#  <div class="grid__section grid__section_top_true grid__section_sticky_none grid__section_theme_default grid__section_theme-changed_false" data-theme="default">
#  <div class="grid__gutter">
#  </div>
#  <div class="grid__content grid__content_top_true grid__content_theme_default grid__content_theme-changed_false">
#  <div class="grid__main grid__main_sticky_none">
#  <div class="grid__cell grid__cell_columns_3" data-columns="12">
#  <div class="grid__module grid__module_top_true grid__module_ready_true" data-count="0" data-module="notification" data-module-id="">
#  <div class="grid__module-inner grid__module-inner_ready_true grid__module-inner_fast_false">
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="grid__gutter">
#  </div>
#  </div>
#  <div class="grid__section grid__section_top_true grid__section_sticky_none grid__section_theme_default grid__section_theme-changed_false" data-theme="default">
#  <div class="grid__gutter">
#  </div>
#  <div class="grid__content grid__content_top_true grid__content_theme_default grid__content_theme-changed_false">
#  <div class="grid__main grid__main_sticky_none">
#  <div class="grid__cell grid__cell_columns_3" data-columns="12">
#  <div class="grid__module grid__module_top_true grid__module_ready_true" data-count="0" data-module="front-heading" data-module-id="">
#  <div class="grid__module-inner grid__module-inner_ready_true grid__module-inner_fast_false">
#  <div class="front-heading">
#  <div class="front-heading__side-bar front-heading__side-bar_section_allergy"></div>
#  <h1 class="front-heading__name front-heading__name_section_allergy">allergy</h1>
#  <div class="front-heading__side-bar front-heading__side-bar_section_allergy"></div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="grid__gutter">
#  </div>
#  </div>
#  <div class="grid__section grid__section_sticky_none grid__section_theme_default grid__section_theme-changed_false grid__section_previous-theme_default grid__section_next-theme_default" data-next-theme="default" data-previous-theme="default" data-theme="default">
#  <div class="grid__gutter">
#  <div class="grid__gutter-content">
#  </div>
#  </div>
#  <div class="grid__content grid__content_theme_default grid__content_theme-changed_false">
#  <div class="grid__main grid__main_sticky_none">
#  <div class="grid__cell grid__cell_columns_2" data-columns="8" data-starting-column="1">
#  <div class="grid__module grid__module_ready_true" data-count="0" data-module="linked-image" data-module-id="b4477ee8-5157-4518-9071-b72ae240f9f8" data-track-movement="false">
#  <div class="grid__module-inner grid__module-inner_ready_true grid__module-inner_fast_false">
#  <div class="linked-image">
#  <div class="linked-image__sizer" data-aspect-ratio="" style="width:750px; height:422px;">
#  <a class="linked-image__link" data-tracking="linked-image/imageLinkClicked" href="">
#  <img alt="Allergy Count" class="linked-image__image" data-caching-profile="wx" data-lazy-loaded="data-lazy-loaded" data-lazy-loader="http://cdn.tegna-media.com/kvue/weather/allergy16x9.jpg" src="http://cdn.tegna-media.com/kvue/weather/allergy16x9.jpg" style="opacity: 1;"/>
#  <noscript>
#                  &lt;img class="linked-image__image" src="http://cdn.tegna-media.com/kvue/weather/allergy16x9.jpg" alt="Allergy Count" /&gt;
#              </noscript>
#  </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="grid__module grid__module_ready_true" data-count="0" data-module="linked-image" data-module-id="b4477ee8-5157-4518-9071-b72ae240f9f8" data-track-movement="false">
#  <div class="grid__module-inner grid__module-inner_ready_true grid__module-inner_fast_false">
#  <div class="linked-image">
#  <div class="linked-image__sizer" data-aspect-ratio="" style="width:750px; height:422px;">
#  <a class="linked-image__link" data-tracking="linked-image/imageLinkClicked" href="">
#  <img alt="Allergy Forecast" class="linked-image__image" data-caching-profile="wx" data-lazy-loaded="data-lazy-loaded" data-lazy-loader="http://cdn.tegna-media.com/kvue/weather/allergy_forecast16x9.jpg" src="http://cdn.tegna-media.com/kvue/weather/allergy_forecast16x9.jpg" style="opacity: 1;"/>
#  <noscript>
#                  &lt;img class="linked-image__image" src="http://cdn.tegna-media.com/kvue/weather/allergy_forecast16x9.jpg" alt="Allergy Forecast" /&gt;
#              </noscript>
#  </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="grid__cell grid__cell_columns_1" data-columns="4" data-starting-column="9">
#  <div class="grid__module grid__module_ready_true" data-count="0" data-module="ad" data-module-id="2d60ed3a-b39c-4bca-9d4c-a1dbd607e57f" data-track-movement="false">
#  <div class="grid__module-inner grid__module-inner_ready_true grid__module-inner_fast_false">
#  <div class="ad ad_border_true ad_position_front_atf" data-google-query-id="CLit59i2leUCFUuVAQodP9wGqA" data-model-refresh="none" data-model-refresh-limit="none" data-model-settings='{"ad":{"name":"front_atf","div":"front_atf","sizes":[[300,250]]},"targeting":{"main_front":["false"],"pgtype":["subindex"]}}' id="front_atf"><div id="google_ads_iframe_/32805352/tx-austin-KVUE-B3350_DesktopTablet/front_atf/weather/allergy-forecast_0__container__" style="border: 0pt none; display: inline-block; width: 300px; height: 250px;"><iframe data-google-container-id="1" data-is-safeframe="true" data-load-complete="true" frameborder="0" height="250" id="google_ads_iframe_/32805352/tx-austin-KVUE-B3350_DesktopTablet/front_atf/weather/allergy-forecast_0" marginheight="0" marginwidth="0" name="" sandbox="allow-forms allow-pointer-lock allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" scrolling="no" src="https://tpc.googlesyndication.com/safeframe/1-0-35/html/container.html" style="border: 0px; vertical-align: bottom;" title="3rd party ad content" width="300"></iframe></div></div>
#  <noscript>
#          &lt;div class="ad__nojs-placeholder" style="height:90px;border:2px solid #e6e6e6"&gt;&lt;/div&gt;
#      </noscript>
#  </div>
#  </div>
#  <div class="grid__module grid__module_ready_true" data-count="1" data-module="text-only-headline-list" data-module-id="267f7194-227e-465a-8563-46ff79275bce" data-track-movement="false">
#  <div class="grid__module-inner grid__module-inner_ready_true grid__module-inner_fast_false">
#  <div class="text-only-headline-list">
#  <h2 class="text-only-headline-list__title">Austin Allergy</h2>
#  <ul class="text-only-headline-list__list">
#  <li class="text-only-headline-list__item">
#  <div class="text-only-headline-list__headline">
#  <a class="text-only-headline-list__link" href="/article/weather/allergy-forecast/allergy-report-austin-allergies/269-44055429">
#                              Today's Allergy Report
#                          </a>
#  </div>
#  <div class="text-only-headline-list__meta">
#  <div class="text-only-headline-list__category headline-list__category_section_allergy-forecast">
#  <a class="text-only-headline-list__link" data-tracking="text-only-headline-list/categoryLinkClicked/allergy-forecast" href="/section/weather/allergy-forecast">ALLERGY-FORECAST</a>
#  </div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="grid__gutter">
#  <div class="grid__gutter-content">
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="grid__section-group grid__section-group_theme_default">
#  <div class="grid__section grid__section_sticky_none grid__section_theme_default grid__section_theme-changed_false grid__section_previous-theme_default grid__section_next-theme_default" data-next-theme="default" data-previous-theme="default" data-theme="default">
#  <div class="grid__gutter">
#  <div class="grid__gutter-content">
#  </div>
#  </div>
#  <div class="grid__content grid__content_theme_default grid__content_theme-changed_false">
#  <div class="grid__main grid__main_sticky_none">
#  <div class="grid__cell grid__cell_columns_3" data-columns="12" data-starting-column="1">
#  <div class="grid__module grid__module_ready_true" data-count="0" data-module="ad" data-module-id="2d60ed3a-b39c-4bca-9d4c-a1dbd607e57f" data-track-movement="false">
#  <div class="grid__module-inner grid__module-inner_ready_true grid__module-inner_fast_false">
#  <div class="ad ad_border_true ad_position_front_high_impact" data-google-query-id="CLmt59i2leUCFUuVAQodP9wGqA" data-model-refresh="none" data-model-refresh-limit="none" data-model-settings='{"ad":{"name":"front_high_impact","div":"front_high_impact","sizes":[[1140,286],[1140,600],[1140,635],[728,90],[970,250],[970,66],[970,90],[960,66]]},"targeting":{"main_front":["false"],"pgtype":["subindex"]}}' id="front_high_impact"><div id="google_ads_iframe_/32805352/tx-austin-KVUE-B3350_DesktopTablet/front_high_impact/weather/allergy-forecast_0__container__" style="border: 0pt none;"><iframe data-google-container-id="2" data-load-complete="true" frameborder="0" height="90" id="google_ads_iframe_/32805352/tx-austin-KVUE-B3350_DesktopTablet/front_high_impact/weather/allergy-forecast_0" marginheight="0" marginwidth="0" name="google_ads_iframe_/32805352/tx-austin-KVUE-B3350_DesktopTablet/front_high_impact/weather/allergy-forecast_0" scrolling="no" srcdoc="" style="border: 0px; vertical-align: bottom;" title="3rd party ad content" width="728"></iframe></div></div>
#  <noscript>
#          &lt;div class="ad__nojs-placeholder" style="height:90px;border:2px solid #e6e6e6"&gt;&lt;/div&gt;
#      </noscript>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="grid__gutter">
#  <div class="grid__gutter-content">
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="grid__section-group grid__section-group_theme_default">
#  <div class="grid__section grid__section_sticky_none grid__section_theme_default grid__section_theme-changed_false grid__section_previous-theme_default grid__section_next-theme_default" data-next-theme="default" data-previous-theme="default" data-theme="default">
#  <div class="grid__gutter">
#  <div class="grid__gutter-content">
#  </div>
#  </div>
#  <div class="grid__content grid__content_theme_default grid__content_theme-changed_false">
#  <div class="grid__main grid__main_sticky_none">
#  <div class="grid__cell grid__cell_columns_3" data-columns="12" data-starting-column="1">
#  <div class="grid__module grid__module_ready_true" data-count="12" data-module="featured-videos" data-module-id="1ea2d188-66e2-4b0e-ab58-d1a302ccb9cb" data-track-movement="false">
#  <div class="grid__module-inner grid__module-inner_ready_true grid__module-inner_fast_false">
#  <div class="featured-videos" style="visibility: visible; height: auto;">
#  <h2 class="featured-videos__title">Featured Videos</h2>
#  <div class="featured-videos__items slick-initialized slick-slider"><div class="featured-videos__arrow-section featured-videos__previous-arrow-section slick-arrow" style=""><div class="featured-videos__arrow featured-videos__arrow-prev"></div></div>
#  <div aria-live="polite" class="slick-list draggable"><div class="slick-track" role="listbox" style="opacity: 1; width: 6588px; transform: translate3d(-1098px, 0px, 0px);"><div aria-hidden="true" class="featured-videos__item slick-slide slick-cloned" data-slick-index="-3" style="width: 358px;" tabindex="-1">
#  <div class="featured-videos__container">
#  <div class="featured-videos__asset">
#  <div class="featured-videos__aspect-ratio-enforcer">
#  <div class="featured-videos__aspect-ratio-enforced" data-aspect-ratio="">
#  <a class="featured-videos__link" data-tracking="featured-videos/LinkClicked" href="/video/money/bbb-watch-out-for-census-scammers/269-ae8d1db3-9e77-431e-b096-987710816dca" tabindex="-1">
#  <img class="featured-videos__image slick-loading" data-lazy="https://media.kvue.com/assets/KVUE/images/99b0f069-3240-483b-9faf-c029c9d4434a/99b0f069-3240-483b-9faf-c029c9d4434a_360x203.jpg"/>
#  <noscript>
#                                                  &lt;img class="featured-videos__image" src="https://media.kvue.com/assets/KVUE/images/99b0f069-3240-483b-9faf-c029c9d4434a/99b0f069-3240-483b-9faf-c029c9d4434a_360x203.jpg" /&gt;
#                                              </noscript>
#  <div class="featured-videos__play"></div>
#  <script type="application/ld+json">
#              {
#              "@context": "http://schema.org",
#              "@type": "VideoObject",
#              "name": "BBB: Watch out for Census scammers",
#              "description": "The Census Bureau will conduct its survey in 2020 and sadly scammers are trying to take advantage. Carlos Villalobos from BBB is here to talk about it.",
#              "thumbnailUrl": "https://media.kvue.com/assets/KVUE/images/99b0f069-3240-483b-9faf-c029c9d4434a/99b0f069-3240-483b-9faf-c029c9d4434a_1140x641.jpg",
#              "uploadDate": "10/11/2019 5:42:12 PM",
#              "duration": "251",
#              "contentUrl": "https://www.kvue.com/video/money/bbb-watch-out-for-census-scammers/269-ae8d1db3-9e77-431e-b096-987710816dca",
#              "embedUrl": "https://media.kvue.com/embeds/video/ae8d1db3-9e77-431e-b096-987710816dca/iframe"
#              }
#          </script>
#  </a>
#  </div>
#  </div>
#  </div>
#  <div class="featured-videos__info">
#  <section class="featured-videos__headline">
#  <a class="featured-videos__link dot-ellipsis dot-height-69 dot-timer-update" data-tracking="featured-videos/headlineLinkClicked" href="/video/money/bbb-watch-out-for-census-scammers/269-ae8d1db3-9e77-431e-b096-987710816dca" style="overflow-wrap: break-word;" tabindex="-1">BBB: Watch out for Census scammers</a>
#  </section>
#  <div class="featured-videos__info-container">
#  <div class="featured-videos__category featured-videos__category_section_money">
#  <a data-tracking="story/categoryLinkClicked/money" href="/section/money" tabindex="-1">MONEY</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="featured-videos__item slick-slide slick-cloned" data-slick-index="-2" style="width: 358px;" tabindex="-1">
#  <div class="featured-videos__container">
#  <div class="featured-videos__asset">
#  <div class="featured-videos__aspect-ratio-enforcer">
#  <div class="featured-videos__aspect-ratio-enforced" data-aspect-ratio="">
#  <a class="featured-videos__link" data-tracking="featured-videos/LinkClicked" href="/video/life/animals/national-geos-simon-and-siouxsie-of-snake-city-in-austin/269-dc794b27-3793-4d40-a33e-1c0c94eddb53" tabindex="-1">
#  <img class="featured-videos__image slick-loading" data-lazy="https://media.kvue.com/assets/KVUE/images/bf94d056-428f-4a43-9ba3-bfa630b1ef28/bf94d056-428f-4a43-9ba3-bfa630b1ef28_360x203.jpg"/>
#  <noscript>
#                                                  &lt;img class="featured-videos__image" src="https://media.kvue.com/assets/KVUE/images/bf94d056-428f-4a43-9ba3-bfa630b1ef28/bf94d056-428f-4a43-9ba3-bfa630b1ef28_360x203.jpg" /&gt;
#                                              </noscript>
#  <div class="featured-videos__play"></div>
#  <script type="application/ld+json">
#              {
#              "@context": "http://schema.org",
#              "@type": "VideoObject",
#              "name": "National Geographic&amp;#39;s Simon and Siouxsie of Snake City in Austin",
#              "description": "National Geographic’s Simon and Siouxsie of Snake City will be at the Austin Zoo meeting fans.",
#              "thumbnailUrl": "https://media.kvue.com/assets/KVUE/images/bf94d056-428f-4a43-9ba3-bfa630b1ef28/bf94d056-428f-4a43-9ba3-bfa630b1ef28_1140x641.jpg",
#              "uploadDate": "10/11/2019 5:36:57 PM",
#              "duration": "180",
#              "contentUrl": "https://www.kvue.com/video/life/animals/national-geos-simon-and-siouxsie-of-snake-city-in-austin/269-dc794b27-3793-4d40-a33e-1c0c94eddb53",
#              "embedUrl": "https://media.kvue.com/embeds/video/dc794b27-3793-4d40-a33e-1c0c94eddb53/iframe"
#              }
#          </script>
#  </a>
#  </div>
#  </div>
#  </div>
#  <div class="featured-videos__info">
#  <section class="featured-videos__headline">
#  <a class="featured-videos__link dot-ellipsis dot-height-69 dot-timer-update" data-tracking="featured-videos/headlineLinkClicked" href="/video/life/animals/national-geos-simon-and-siouxsie-of-snake-city-in-austin/269-dc794b27-3793-4d40-a33e-1c0c94eddb53" style="overflow-wrap: break-word;" tabindex="-1">National Geographic's Simon and Siouxsie of Snake City in Austin</a>
#  </section>
#  <div class="featured-videos__info-container">
#  <div class="featured-videos__category featured-videos__category_section_animals">
#  <a data-tracking="story/categoryLinkClicked/animals" href="/section/life/animals" tabindex="-1">ANIMALS</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="featured-videos__item slick-slide slick-cloned" data-slick-index="-1" style="width: 358px;" tabindex="-1">
#  <div class="featured-videos__container">
#  <div class="featured-videos__asset">
#  <div class="featured-videos__aspect-ratio-enforcer">
#  <div class="featured-videos__aspect-ratio-enforced" data-aspect-ratio="">
#  <a class="featured-videos__link" data-tracking="featured-videos/LinkClicked" href="/video/weather/weather/269-ddb05f04-cb73-4159-97b3-3acbdef53357" tabindex="-1">
#  <img class="featured-videos__image slick-loading" data-lazy="https://media.kvue.com/assets/KVUE/images/01db577b-85a2-41c4-9cad-4e24b6baafe2/01db577b-85a2-41c4-9cad-4e24b6baafe2_360x203.png"/>
#  <noscript>
#                                                  &lt;img class="featured-videos__image" src="https://media.kvue.com/assets/KVUE/images/01db577b-85a2-41c4-9cad-4e24b6baafe2/01db577b-85a2-41c4-9cad-4e24b6baafe2_360x203.png" /&gt;
#                                              </noscript>
#  <div class="featured-videos__play"></div>
#  <script type="application/ld+json">
#              {
#              "@context": "http://schema.org",
#              "@type": "VideoObject",
#              "name": "Friday weather",
#              "description": "Friday weather",
#              "thumbnailUrl": "https://media.kvue.com/assets/KVUE/images/01db577b-85a2-41c4-9cad-4e24b6baafe2/01db577b-85a2-41c4-9cad-4e24b6baafe2_1140x641.png",
#              "uploadDate": "10/11/2019 2:15:54 PM",
#              "duration": "134",
#              "contentUrl": "https://www.kvue.com/video/weather/weather/269-ddb05f04-cb73-4159-97b3-3acbdef53357",
#              "embedUrl": "https://media.kvue.com/embeds/video/ddb05f04-cb73-4159-97b3-3acbdef53357/iframe"
#              }
#          </script>
#  </a>
#  </div>
#  </div>
#  </div>
#  <div class="featured-videos__info">
#  <section class="featured-videos__headline">
#  <a class="featured-videos__link dot-ellipsis dot-height-69 dot-timer-update" data-tracking="featured-videos/headlineLinkClicked" href="/video/weather/weather/269-ddb05f04-cb73-4159-97b3-3acbdef53357" style="overflow-wrap: break-word;" tabindex="-1">Friday weather</a>
#  </section>
#  <div class="featured-videos__info-container">
#  <div class="featured-videos__category featured-videos__category_section_weather">
#  <a data-tracking="story/categoryLinkClicked/weather" href="/section/weather" tabindex="-1">WEATHER</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div><div aria-describedby="slick-slide10" aria-hidden="false" class="featured-videos__item slick-slide slick-current slick-active" data-slick-index="0" role="option" style="width: 358px;" tabindex="-1">
#  <div class="featured-videos__container">
#  <div class="featured-videos__asset">
#  <div class="featured-videos__aspect-ratio-enforcer">
#  <div class="featured-videos__aspect-ratio-enforced" data-aspect-ratio="">
#  <a class="featured-videos__link" data-tracking="featured-videos/LinkClicked" href="/video/news/politics/national-politics/democratic-candidates-prepare-4th-debate/269-4c75d98e-6e98-4a47-b3cc-a130794d7182" tabindex="0">
# ...
#  <noscript>
#          &lt;div class="ad__nojs-placeholder" style="height:90px;border:2px solid #e6e6e6"&gt;&lt;/div&gt;
#      </noscript>
#  </div>,
#  <div class="ad ad_border_true ad_position_front_leaderboard_btf" data-google-query-id="CMnY6di2leUCFUuVAQodP9wGqA" data-model-refresh="none" data-model-refresh-limit="none" data-model-settings='{"ad":{"name":"front_leaderboard_btf","div":"front_leaderboard_btf","sizes":[[728,90]]},"targeting":{"main_front":["false"],"pgtype":["subindex"]}}' id="front_leaderboard_btf"><div id="google_ads_iframe_/32805352/tx-austin-KVUE-B3350_DesktopTablet/front_leaderboard_btf/weather/allergy-forecast_0__container__" style="border: 0pt none; display: inline-block; width: 728px; height: 90px;"><iframe data-google-container-id="3" data-is-safeframe="true" data-load-complete="true" frameborder="0" height="90" id="google_ads_iframe_/32805352/tx-austin-KVUE-B3350_DesktopTablet/front_leaderboard_btf/weather/allergy-forecast_0" marginheight="0" marginwidth="0" name="" sandbox="allow-forms allow-pointer-lock allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" scrolling="no" src="https://tpc.googlesyndication.com/safeframe/1-0-35/html/container.html" style="border: 0px; vertical-align: bottom;" title="3rd party ad content" width="728"></iframe></div></div>,
#  <div id="google_ads_iframe_/32805352/tx-austin-KVUE-B3350_DesktopTablet/front_leaderboard_btf/weather/allergy-forecast_0__container__" style="border: 0pt none; display: inline-block; width: 728px; height: 90px;"><iframe data-google-container-id="3" data-is-safeframe="true" data-load-complete="true" frameborder="0" height="90" id="google_ads_iframe_/32805352/tx-austin-KVUE-B3350_DesktopTablet/front_leaderboard_btf/weather/allergy-forecast_0" marginheight="0" marginwidth="0" name="" sandbox="allow-forms allow-pointer-lock allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" scrolling="no" src="https://tpc.googlesyndication.com/safeframe/1-0-35/html/container.html" style="border: 0px; vertical-align: bottom;" title="3rd party ad content" width="728"></iframe></div>,
#  <div class="grid__gutter">
#  <div class="grid__gutter-content">
#  </div>
#  </div>,
#  <div class="grid__gutter-content">
#  </div>,
#  <div class="page__footer">
#  <div class="footer">
#  <div class="footer__inner">
#  <div class="footer__social">
#  <div class="social">
#  <ul class="social__list social__list_align_center">
#  <li class="social__item">
#  <a class="social__link" href="https://www.facebook.com/KVUEinsider" target="_blank">
#  <span class="social__icon social__icon_type_facebook"><svg height="16" viewbox="0 0 17 16" width="17" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <image data-name="Vector Smart Object" height="16" id="Vector_Smart_Object" width="17" xlink:href="data:img/png;base64,..."/>
#  </svg></span>
#  </a>
#  </li>
#  <li class="social__item">
#  <a class="social__link" href="https://twitter.com/intent/user?screen_name=KVUE" target="_blank">
#  <span class="social__icon social__icon_type_twitter"><svg height="16" viewbox="0 0 19 16" width="19" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <image data-name="Vector Smart Object" height="16" id="Vector_Smart_Object" width="19" xlink:href="data:img/png;base64,..."/>
#  </svg></span>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <div class="footer__menu">
#  <ul class="footer__list">
#  <li class="footer__item"><a class="footer__link" href="https://www.jobs.net/jobs/tegna/en-us/all-jobs/?companyf=KVUE" target="_blank">Jobs</a></li>
#  <li class="footer__item"><a class="footer__link" href="/terms" target="_self">Terms of Service</a></li>
#  <li class="footer__item"><a class="footer__link" href="/privacy" target="_self">Privacy Notice</a></li>
#  <li class="footer__item"><a class="footer__link" href="/privacy" target="_self">Your California Privacy Notice</a></li>
#  </ul>
#  <ul class="footer__list">
#  <li class="footer__item"><a class="footer__link" href="/adchoices" target="_self">Ad Choices</a></li>
#  <li class="footer__item"><a class="footer__link" href="https://interactive.kvue.com/pdfs/AustinTX_EEO_Public_File%202018_2019.pdf" target="_blank">EEO Public File Report</a></li>
#  <li class="footer__item"><a class="footer__link" href="/fcc-public-inspection-file" target="_self">FCC Online Public Inspection File</a></li>
#  <li class="footer__item"><a class="footer__link" href="/closed-captioning" target="_self">Closed Caption Procedures</a></li>
#  </ul>
#  </div>
#  <div class="footer__copyright">
#              © 2019 KVUE-TV. All Rights Reserved.
#          </div>
#  </div>
#  </div>
#  <div class="ad ad_border_true ad_position_exit_interstitial" data-google-query-id="CLut59i2leUCFUuVAQodP9wGqA" data-model-refresh="none" data-model-refresh-limit="none" data-model-settings='{"ad":{"name":"exit_interstitial","div":"exit_interstitial","sizes":[[1,1]]}}' id="exit_interstitial"><div id="google_ads_iframe_/32805352/tx-austin-KVUE-B3350_DesktopTablet/exit_interstitial/weather/allergy-forecast_0__container__" style="border: 0pt none;"><iframe data-google-container-id="4" data-load-complete="true" frameborder="0" height="1" id="google_ads_iframe_/32805352/tx-austin-KVUE-B3350_DesktopTablet/exit_interstitial/weather/allergy-forecast_0" marginheight="0" marginwidth="0" name="google_ads_iframe_/32805352/tx-austin-KVUE-B3350_DesktopTablet/exit_interstitial/weather/allergy-forecast_0" scrolling="no" srcdoc="" style="border: 0px; vertical-align: bottom;" title="3rd party ad content" width="1"></iframe></div></div>
#  <noscript>
#          &lt;div class="ad__nojs-placeholder" style="height:90px;border:2px solid #e6e6e6"&gt;&lt;/div&gt;
#      </noscript>
#  </div>,
#  <div class="footer">
#  <div class="footer__inner">
#  <div class="footer__social">
#  <div class="social">
#  <ul class="social__list social__list_align_center">
#  <li class="social__item">
#  <a class="social__link" href="https://www.facebook.com/KVUEinsider" target="_blank">
#  <span class="social__icon social__icon_type_facebook"><svg height="16" viewbox="0 0 17 16" width="17" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <image data-name="Vector Smart Object" height="16" id="Vector_Smart_Object" width="17" xlink:href="data:img/png;base64,..."/>
#  </svg></span>
#  </a>
#  </li>
#  <li class="social__item">
#  <a class="social__link" href="https://twitter.com/intent/user?screen_name=KVUE" target="_blank">
#  <span class="social__icon social__icon_type_twitter"><svg height="16" viewbox="0 0 19 16" width="19" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <image data-name="Vector Smart Object" height="16" id="Vector_Smart_Object" width="19" xlink:href="data:img/png;base64,..."/>
#  </svg></span>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <div class="footer__menu">
#  <ul class="footer__list">
#  <li class="footer__item"><a class="footer__link" href="https://www.jobs.net/jobs/tegna/en-us/all-jobs/?companyf=KVUE" target="_blank">Jobs</a></li>
#  <li class="footer__item"><a class="footer__link" href="/terms" target="_self">Terms of Service</a></li>
#  <li class="footer__item"><a class="footer__link" href="/privacy" target="_self">Privacy Notice</a></li>
#  <li class="footer__item"><a class="footer__link" href="/privacy" target="_self">Your California Privacy Notice</a></li>
#  </ul>
#  <ul class="footer__list">
#  <li class="footer__item"><a class="footer__link" href="/adchoices" target="_self">Ad Choices</a></li>
#  <li class="footer__item"><a class="footer__link" href="https://interactive.kvue.com/pdfs/AustinTX_EEO_Public_File%202018_2019.pdf" target="_blank">EEO Public File Report</a></li>
#  <li class="footer__item"><a class="footer__link" href="/fcc-public-inspection-file" target="_self">FCC Online Public Inspection File</a></li>
#  <li class="footer__item"><a class="footer__link" href="/closed-captioning" target="_self">Closed Caption Procedures</a></li>
#  </ul>
#  </div>
#  <div class="footer__copyright">
#              © 2019 KVUE-TV. All Rights Reserved.
#          </div>
#  </div>
#  </div>,
#  <div class="footer__inner">
#  <div class="footer__social">
#  <div class="social">
#  <ul class="social__list social__list_align_center">
#  <li class="social__item">
#  <a class="social__link" href="https://www.facebook.com/KVUEinsider" target="_blank">
#  <span class="social__icon social__icon_type_facebook"><svg height="16" viewbox="0 0 17 16" width="17" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <image data-name="Vector Smart Object" height="16" id="Vector_Smart_Object" width="17" xlink:href="data:img/png;base64,..."/>
#  </svg></span>
#  </a>
#  </li>
#  <li class="social__item">
#  <a class="social__link" href="https://twitter.com/intent/user?screen_name=KVUE" target="_blank">
#  <span class="social__icon social__icon_type_twitter"><svg height="16" viewbox="0 0 19 16" width="19" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <image data-name="Vector Smart Object" height="16" id="Vector_Smart_Object" width="19" xlink:href="data:img/png;base64,..."/>
#  </svg></span>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <div class="footer__menu">
#  <ul class="footer__list">
#  <li class="footer__item"><a class="footer__link" href="https://www.jobs.net/jobs/tegna/en-us/all-jobs/?companyf=KVUE" target="_blank">Jobs</a></li>
#  <li class="footer__item"><a class="footer__link" href="/terms" target="_self">Terms of Service</a></li>
#  <li class="footer__item"><a class="footer__link" href="/privacy" target="_self">Privacy Notice</a></li>
#  <li class="footer__item"><a class="footer__link" href="/privacy" target="_self">Your California Privacy Notice</a></li>
#  </ul>
#  <ul class="footer__list">
#  <li class="footer__item"><a class="footer__link" href="/adchoices" target="_self">Ad Choices</a></li>
#  <li class="footer__item"><a class="footer__link" href="https://interactive.kvue.com/pdfs/AustinTX_EEO_Public_File%202018_2019.pdf" target="_blank">EEO Public File Report</a></li>
#  <li class="footer__item"><a class="footer__link" href="/fcc-public-inspection-file" target="_self">FCC Online Public Inspection File</a></li>
#  <li class="footer__item"><a class="footer__link" href="/closed-captioning" target="_self">Closed Caption Procedures</a></li>
#  </ul>
#  </div>
#  <div class="footer__copyright">
#              © 2019 KVUE-TV. All Rights Reserved.
#          </div>
#  </div>,
#  <div class="footer__social">
#  <div class="social">
#  <ul class="social__list social__list_align_center">
#  <li class="social__item">
#  <a class="social__link" href="https://www.facebook.com/KVUEinsider" target="_blank">
#  <span class="social__icon social__icon_type_facebook"><svg height="16" viewbox="0 0 17 16" width="17" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <image data-name="Vector Smart Object" height="16" id="Vector_Smart_Object" width="17" xlink:href="data:img/png;base64,..."/>
#  </svg></span>
#  </a>
#  </li>
#  <li class="social__item">
#  <a class="social__link" href="https://twitter.com/intent/user?screen_name=KVUE" target="_blank">
#  <span class="social__icon social__icon_type_twitter"><svg height="16" viewbox="0 0 19 16" width="19" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <image data-name="Vector Smart Object" height="16" id="Vector_Smart_Object" width="19" xlink:href="data:img/png;base64,..."/>
#  </svg></span>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>,
#  <div class="social">
#  <ul class="social__list social__list_align_center">
#  <li class="social__item">
#  <a class="social__link" href="https://www.facebook.com/KVUEinsider" target="_blank">
#  <span class="social__icon social__icon_type_facebook"><svg height="16" viewbox="0 0 17 16" width="17" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <image data-name="Vector Smart Object" height="16" id="Vector_Smart_Object" width="17" xlink:href="data:img/png;base64,..."/>
#  </svg></span>
#  </a>
#  </li>
#  <li class="social__item">
#  <a class="social__link" href="https://twitter.com/intent/user?screen_name=KVUE" target="_blank">
#  <span class="social__icon social__icon_type_twitter"><svg height="16" viewbox="0 0 19 16" width="19" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <image data-name="Vector Smart Object" height="16" id="Vector_Smart_Object" width="19" xlink:href="data:img/png;base64,..."/>
#  </svg></span>
#  </a>
#  </li>
#  </ul>
#  </div>,
#  <div class="footer__menu">
#  <ul class="footer__list">
#  <li class="footer__item"><a class="footer__link" href="https://www.jobs.net/jobs/tegna/en-us/all-jobs/?companyf=KVUE" target="_blank">Jobs</a></li>
#  <li class="footer__item"><a class="footer__link" href="/terms" target="_self">Terms of Service</a></li>
#  <li class="footer__item"><a class="footer__link" href="/privacy" target="_self">Privacy Notice</a></li>
#  <li class="footer__item"><a class="footer__link" href="/privacy" target="_self">Your California Privacy Notice</a></li>
#  </ul>
#  <ul class="footer__list">
#  <li class="footer__item"><a class="footer__link" href="/adchoices" target="_self">Ad Choices</a></li>
#  <li class="footer__item"><a class="footer__link" href="https://interactive.kvue.com/pdfs/AustinTX_EEO_Public_File%202018_2019.pdf" target="_blank">EEO Public File Report</a></li>
#  <li class="footer__item"><a class="footer__link" href="/fcc-public-inspection-file" target="_self">FCC Online Public Inspection File</a></li>
#  <li class="footer__item"><a class="footer__link" href="/closed-captioning" target="_self">Closed Caption Procedures</a></li>
#  </ul>
#  </div>,
#  <div class="footer__copyright">
#              © 2019 KVUE-TV. All Rights Reserved.
#          </div>,
#  <div class="ad ad_border_true ad_position_exit_interstitial" data-google-query-id="CLut59i2leUCFUuVAQodP9wGqA" data-model-refresh="none" data-model-refresh-limit="none" data-model-settings='{"ad":{"name":"exit_interstitial","div":"exit_interstitial","sizes":[[1,1]]}}' id="exit_interstitial"><div id="google_ads_iframe_/32805352/tx-austin-KVUE-B3350_DesktopTablet/exit_interstitial/weather/allergy-forecast_0__container__" style="border: 0pt none;"><iframe data-google-container-id="4" data-load-complete="true" frameborder="0" height="1" id="google_ads_iframe_/32805352/tx-austin-KVUE-B3350_DesktopTablet/exit_interstitial/weather/allergy-forecast_0" marginheight="0" marginwidth="0" name="google_ads_iframe_/32805352/tx-austin-KVUE-B3350_DesktopTablet/exit_interstitial/weather/allergy-forecast_0" scrolling="no" srcdoc="" style="border: 0px; vertical-align: bottom;" title="3rd party ad content" width="1"></iframe></div></div>,
#  <div id="google_ads_iframe_/32805352/tx-austin-KVUE-B3350_DesktopTablet/exit_interstitial/weather/allergy-forecast_0__container__" style="border: 0pt none;"><iframe data-google-container-id="4" data-load-complete="true" frameborder="0" height="1" id="google_ads_iframe_/32805352/tx-austin-KVUE-B3350_DesktopTablet/exit_interstitial/weather/allergy-forecast_0" marginheight="0" marginwidth="0" name="google_ads_iframe_/32805352/tx-austin-KVUE-B3350_DesktopTablet/exit_interstitial/weather/allergy-forecast_0" scrolling="no" srcdoc="" style="border: 0px; vertical-align: bottom;" title="3rd party ad content" width="1"></iframe></div>]
